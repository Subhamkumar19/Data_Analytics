# %% [markdown]
# ## 1. Comments :
#     are the non-executable piece of code that is used to increase the reusability of our program.
# <pre>1. Single line comment : represented with '#'.
# 2. Multi line comment : represented with '''...''' or """ .... """</pre>

# %%
# this is a single line comment

# %%
""" This is a multiline
comment 
and 
that's all"""
# Out:
# " This is a multiline\ncomment \nand \nthat's all"

# %% [markdown]
# ## 2. Keywords : Reserved or Pre-defined words present in python library.
# <pre>Python has 35+ key words</pre>

# %% [markdown]
# ## 3. Identifiers : are the names that we give inorder to identify any variable, class, function
# <pre> while naming an identifier we must follow "Identifire's Rule".</pre>

# %%
# Rule 1 : cannot use any keyword.
else =12
# Out:
#   Cell In[3], line 2
#     else =12
#     ^
# SyntaxError: invalid syntax

# %%
# Rule 2 : we cannot start an Identifier's name with Disits.
var12 ="apple"

# %%
# Rule 3 : cannot use any special character except underscore '_'
var$_1 =1234
# Out:
#   Cell In[5], line 2
#     var$_1 =1234
#        ^
# SyntaxError: invalid syntax

# %%
var_1= 12

# %%
# Rule 5 : python is a case sensitive Language i.e: 'A' !='a'

# %%
a= 'apple'
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 a= 'apple'
# ----> 2 print(A)
#
# NameError: name 'A' is not defined

# %% [markdown]
# ### Variables : are the contaoiners that helps us to store values in it.
# <pre> It is also used for memory allocation. </pre>

# %%
var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 var
#
# NameError: name 'var' is not defined

# %%
12345
# Out:
# 12345

# %% [markdown]
# ## 5. Datatypes : are used to represent the kind of data we are dealing with.
# <pre> data types are of two type primary and sequential
# primary contains 2 types of data one is numeric and another is non-numeric
# Numeric data is Int float and complex
# non numeric has boolean and String </pre>

# %%
# int 
var = 123
type(var)
# Out:
# int

# %%
var1 = 123.5
type(var1)
# Out:
# float

# %%
var3 =654+11j
type (var3)
# Out:
# complex

# %%
#2 Non-Numeric data types 
#bool 
var5 = True
type(var5)
# Out:
# bool

# %%
# string
var4='qwerty'
type(var4)
# Out:
# str

# %%
# Sequential Datatype:
# 1. List : are collection of individual items separated by , and enclosed within a square bracket []
a=[12,23,45 , True, "subham", 67+9j]
type(a)
# Out:
# list

# %%
# 2. Tuple :mare collection of sigle elements separated by , and enclosed within a ()
b=(12,23,45 , True, "subham", 67+9j)
type(b)
# Out:
# tuple

# %%
# 3. Set : set are also the collecyion of single items separated by , and enclosed within a {}
c= {12,23,45,'star',67+5j}
type(c)
# Out:
# set

# %%
# 4. Dictionary : these are a collection of paired elements (key:value) enclosed within {}
d={1:'string 123',14:'False'}
type(d)
# Out:
# dict

# %% [markdown]
# ## Input / Output in Python

# %%
## input() : a predefined function that allows the user to give their values.

# %%
input("enter the data" )
