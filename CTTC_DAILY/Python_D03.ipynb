# %% [markdown]
# # Operators

# %% [markdown]
# ### Special operators

# %%
a=6
b=6

# %%
a is b
# Out:
# True

# %%
c=-6
d=-6

# %%
c is d
# Out:
# False

# %%
a=257
b=257
a is b
# Out:
# False

# %%
a=5
print(id (a))
b=5
print(id(b))
a is b
# Out:
# 140729601043000
# 140729601043000
# True

# %%
m='abcd_5'
n='abcd_5'
m is n
# Out:
# True

# %%
x=[1,2,3,4]
y=[1,2,3,4]

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %% [markdown]
# ## Membership operator - 'in' or 'not in'

# %%
'A' not in 'apple'
# Out:
# True

# %%
'A' in 'apple'
# Out:
# False

# %%
10 in [10,20,30,40]
# Out:
# True

# %% [markdown]
# ## String Operators

# %%
#'+' used to concetenate/ joining strings
'pussy '+'cat 😺'
# Out:
# 'pussy cat 😺'

# %%
# '*' user to replicate/ Duplicate the String
'🍥'*5
# Out:
# '🍥🍥🍥🍥🍥'

# %% [markdown]
# # Type Casting
#     Conversion of data Types

# %%
a= '123'
print(a)
type(a)
# Out:
# 123
# str

# %%
i= int(a)
print(i)
type(i)
# Out:
# 123
# int

# %%
f=float(i)
print(f)
type(f)
# Out:
# 123.0
# float

# %%
c=complex(f)
print(c)
type(c)
# Out:
# (123+0j)
# complex

# %%
a='Hello Everyone'
print(a)
type(a)
# Out:
# Hello Everyone
# str

# %%
l=list(a)
print(l)
type(l)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'E', 'v', 'e', 'r', 'y', 'o', 'n', 'e']
# list

# %%
t=tuple(a)
print(t)
type(t)
# Out:
# ('H', 'e', 'l', 'l', 'o', ' ', 'E', 'v', 'e', 'r', 'y', 'o', 'n', 'e')
# tuple

# %%
s=set(a)
print(s)
type(s)
# Out:
# {'E', 'l', 'y', 'H', 'e', 'r', 'o', 'n', ' ', 'v'}
# set

# %% [markdown]
# ## Conditional Statement: It is used to check the flow of control according top the given condition.
#
# <ul>
#     <li>Single If</li>
#     <li>if-else</li>
#     <li>if-elif-else</li>
#     <li>Nested if</li>
# </ul>

# %% [markdown]
# # Indentention
#     it is one of the most important features in Python.IT Indicates the Block of Code.

# %%
if 10>5:
    print('Greater')
# Out:
# Greater

# %%
if 10>5:
    print('Greater')
# Out:
# Greater

# %%
n=int(input('Enter your number'))
if n>10:
    print(f"Subham the number is {n} greater than 10")
# Out:
# Enter your number 11
# Subham the number is 11 greater than 10

# %%
n=int(input('Enter your number'))
if n%2==0:
    print('Even')
else:
    print('Odd')
# Out:
# Enter your number 10
# Even

# %%
n=int(input('Enter your number'))
if n>=18 and n<100:
    print("Yes You can")
else:
    print("No, You can't")
# Out:
# Enter your number 101
# No, You can't
